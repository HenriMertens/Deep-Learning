# %%
import os
import pandas as pd
import cv2

import os
import json
import ast

import numpy as np
import pandas as pd
import cv2
from scipy.optimize import curve_fit

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import confusion_matrix, classification_report

import tensorflow as tf
from tensorflow.keras import layers, regularizers
from tensorflow.keras.layers import LeakyReLU
from tensorflow.keras.optimizers import SGD, AdamW

from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Flatten, Input
from keras.regularizers import l2
from keras.utils import to_categorical

import keras_tuner as kt

import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.gridspec as gridspec
import zipfile

from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.applications.efficientnet import preprocess_input as pi_efficient
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input as pi_resnet

from tensorflow.keras import layers, models, preprocessing

# %%
base_dir = os.getcwd()

train_path = os.path.join(base_dir, "simpsons-mnist-master", "dataset", "rgb", "train")
test_path = os.path.join(base_dir, "simpsons-mnist-master", "dataset", "rgb", "test")
test_rotated_path = os.path.join(base_dir, "simpsons-mnist-master", "dataset", "rgb", "test_rotated")
test_zoomed_in_path = os.path.join(base_dir, "simpsons-mnist-master", "dataset", "rgb", "test_zoomed_in")
test_zoomed_out_path = os.path.join(base_dir, "simpsons-mnist-master", "dataset", "rgb", "test_zoomed_out")

image_data = []
test_data = []
test_r_data = []
test_zi_data = []
test_zo_data = []

for class_name in os.listdir(train_path):

    class_path = os.path.join(train_path, class_name)

    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            image_data.append((os.path.join(class_path, img_name), class_name))

df_train = pd.DataFrame(image_data, columns=["image_path", "label"])
print(df_train.head())

for class_name in os.listdir(test_path):

    class_path = os.path.join(test_path, class_name)

    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            test_data.append((os.path.join(class_path, img_name), class_name))


df_test = pd.DataFrame(test_data, columns=["image_path", "label"])
print(df_test.head())

for class_name in os.listdir(test_rotated_path):

    class_path = os.path.join(test_rotated_path, class_name)

    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            test_r_data.append((os.path.join(class_path, img_name), class_name))

df_test_r = pd.DataFrame(test_r_data, columns=["image_path", "label"])
print(df_test_r.head())

for class_name in os.listdir(test_zoomed_in_path):

    class_path = os.path.join(test_zoomed_in_path, class_name)

    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            test_zi_data.append((os.path.join(class_path, img_name), class_name))

df_test_zi = pd.DataFrame(test_zi_data, columns=["image_path", "label"])
print(df_test_zi.head())

for class_name in os.listdir(test_zoomed_out_path):

    class_path = os.path.join(test_zoomed_out_path, class_name)

    if os.path.isdir(class_path):
        for img_name in os.listdir(class_path):
            test_zo_data.append((os.path.join(class_path, img_name), class_name))

df_test_zo = pd.DataFrame(test_zo_data, columns=["image_path", "label"])
print(df_test_zo.head())
# Out:
#                                           image_path         label
# 0  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 1  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 2  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 3  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 4  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
#                                           image_path         label
# 0  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 1  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 2  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 3  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 4  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
#                                           image_path         label
# 0  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 1  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 2  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 3  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 4  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
#                                           image_path         label
# 0  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 1  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 2  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 3  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 4  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
#                                           image_path         label
# 0  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 1  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 2  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 3  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson
# 4  c:\Users\Henri\Downloads\Henri\Master HIR\Vakk...  bart_simpson

# %%
def load_image(img_path):
    img = cv2.imread(img_path)
    img = img / 255.0
    return img


df_train["image_array"] = df_train["image_path"].apply(lambda x: load_image(x))

df_test["image_array"] = df_test["image_path"].apply(lambda x: load_image(x))

df_test_r["image_array"] = df_test_r["image_path"].apply(lambda x: load_image(x))

df_test_zi["image_array"] = df_test_zi["image_path"].apply(lambda x: load_image(x))

df_test_zo["image_array"] = df_test_zo["image_path"].apply(lambda x: load_image(x))


sample_img = df_train["image_array"][0]
print(sample_img.shape)
# Out:
# (28, 28, 3)

# %%
num_classes = df_train.label.nunique()
print(num_classes)
# Out:
# 10

# %%
label_encoder = LabelEncoder()
df_train["label_encoded"] = label_encoder.fit_transform(df_train["label"])
df_test["label_encoded"] = label_encoder.transform(df_test["label"])
df_test_r["label_encoded"] = label_encoder.transform(df_test_r["label"])
df_test_zi["label_encoded"] = label_encoder.transform(df_test_zi["label"])
df_test_zo["label_encoded"] = label_encoder.transform(df_test_zo["label"])



X_train_valid = np.stack(df_train["image_array"].values)


y_train_valid = to_categorical(df_train["label_encoded"], num_classes=num_classes)

X_train, X_valid, y_train, y_valid = train_test_split(X_train_valid, y_train_valid, test_size=0.3, random_state=42)

X_test = np.stack(df_test["image_array"].values)
y_test = to_categorical(df_test["label_encoded"], num_classes=num_classes)

X_test_r = np.stack(df_test_r["image_array"].values)
y_test_r = to_categorical(df_test_r["label_encoded"], num_classes=num_classes)

X_test_zi = np.stack(df_test_zi["image_array"].values)
y_test_zi = to_categorical(df_test_zi["label_encoded"], num_classes=num_classes)

X_test_zo = np.stack(df_test_zo["image_array"].values)
y_test_zo = to_categorical(df_test_zo["label_encoded"], num_classes=num_classes)


print(X_train_valid.shape)
print(y_train_valid.shape)
# Out:
# (8000, 28, 28, 3)
# (8000, 10)

# %%
# Preprocess all images of entire dataset
X_train = pi_resnet(X_train)
X_valid = pi_resnet(X_valid)

X_train_resized = tf.image.resize(X_train, (32, 32))
X_valid_resized = tf.image.resize(X_valid, (32, 32))

# Import ResNet50 for transfer learning
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(32, 32, 3))
base_model.trainable = False  # Freeze base model

# %%
data_augmentation = models.Sequential([
    layers.RandomFlip('horizontal'),
    layers.RandomRotation(0.1),
    layers.RandomZoom(0.1),
    layers.RandomTranslation(0.1, 0.1),
    #layers.RandomContrast(0.1),
])


from tensorflow.keras import layers, models

model = models.Sequential([
    data_augmentation,          
    base_model,                 
    layers.GlobalAveragePooling2D(),  
    layers.Dense(512),         
    layers.LeakyReLU(alpha=0.3),  
    layers.Dropout(0.4),        
    layers.Dense(256),        
    layers.LeakyReLU(alpha=0.3),   
    layers.Dropout(0.3),        
    layers.Dense(128),         
    layers.LeakyReLU(alpha=0.3),   
    layers.Dropout(0.2),       
    layers.Dense(num_classes, activation='softmax')  
])




model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(X_train_resized, y_train, 
                    validation_data=(X_valid_resized, y_valid), 
                    epochs=1000, batch_size=64)
# Out:
# Epoch 1/100
# 88/88 [==============================] - 17s 159ms/step - loss: 2.5605 - accuracy: 0.1002 - val_loss: 2.3102 - val_accuracy: 0.0967
# Epoch 2/100
# 88/88 [==============================] - 14s 156ms/step - loss: 2.3715 - accuracy: 0.1077 - val_loss: 2.3020 - val_accuracy: 0.1367
# Epoch 3/100
# 88/88 [==============================] - 13s 151ms/step - loss: 2.3663 - accuracy: 0.0986 - val_loss: 2.2985 - val_accuracy: 0.1033
# Epoch 4/100
# 88/88 [==============================] - 14s 158ms/step - loss: 2.3472 - accuracy: 0.1029 - val_loss: 2.2963 - val_accuracy: 0.1071
# Epoch 5/100
# 88/88 [==============================] - 14s 165ms/step - loss: 2.3436 - accuracy: 0.1061 - val_loss: 2.2991 - val_accuracy: 0.1158
# Epoch 6/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.3384 - accuracy: 0.1141 - val_loss: 2.2935 - val_accuracy: 0.1262
# Epoch 7/100
# 88/88 [==============================] - 15s 174ms/step - loss: 2.3329 - accuracy: 0.1063 - val_loss: 2.2820 - val_accuracy: 0.1304
# Epoch 8/100
# 88/88 [==============================] - 15s 167ms/step - loss: 2.3245 - accuracy: 0.1107 - val_loss: 2.2796 - val_accuracy: 0.1375
# Epoch 9/100
# 88/88 [==============================] - 14s 157ms/step - loss: 2.3263 - accuracy: 0.1154 - val_loss: 2.3017 - val_accuracy: 0.0983
# Epoch 10/100
# 88/88 [==============================] - 14s 157ms/step - loss: 2.3288 - accuracy: 0.1095 - val_loss: 2.2928 - val_accuracy: 0.1142
# Epoch 11/100
# 88/88 [==============================] - 14s 158ms/step - loss: 2.3263 - accuracy: 0.1073 - val_loss: 2.2793 - val_accuracy: 0.1371
# Epoch 12/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.3154 - accuracy: 0.1230 - val_loss: 2.2784 - val_accuracy: 0.1250
# Epoch 13/100
# 88/88 [==============================] - 14s 158ms/step - loss: 2.3196 - accuracy: 0.1138 - val_loss: 2.2735 - val_accuracy: 0.1542
# Epoch 14/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.3137 - accuracy: 0.1150 - val_loss: 2.2779 - val_accuracy: 0.1267
# Epoch 15/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.3041 - accuracy: 0.1214 - val_loss: 2.2836 - val_accuracy: 0.1271
# Epoch 16/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.3092 - accuracy: 0.1275 - val_loss: 2.2799 - val_accuracy: 0.1246
# Epoch 17/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.3049 - accuracy: 0.1209 - val_loss: 2.2739 - val_accuracy: 0.1187
# Epoch 18/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2994 - accuracy: 0.1293 - val_loss: 2.2666 - val_accuracy: 0.1342
# Epoch 19/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2867 - accuracy: 0.1275 - val_loss: 2.2644 - val_accuracy: 0.1346
# Epoch 20/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2942 - accuracy: 0.1348 - val_loss: 2.2573 - val_accuracy: 0.1508
# Epoch 21/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2908 - accuracy: 0.1279 - val_loss: 2.2805 - val_accuracy: 0.1275
# Epoch 22/100
# 88/88 [==============================] - 14s 164ms/step - loss: 2.2893 - accuracy: 0.1293 - val_loss: 2.2577 - val_accuracy: 0.1375
# Epoch 23/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2846 - accuracy: 0.1339 - val_loss: 2.2633 - val_accuracy: 0.1417
# Epoch 24/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2940 - accuracy: 0.1341 - val_loss: 2.2578 - val_accuracy: 0.1542
# Epoch 25/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2797 - accuracy: 0.1409 - val_loss: 2.2671 - val_accuracy: 0.1262
# Epoch 26/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2813 - accuracy: 0.1339 - val_loss: 2.2616 - val_accuracy: 0.1267
# Epoch 27/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2792 - accuracy: 0.1346 - val_loss: 2.2664 - val_accuracy: 0.1304
# Epoch 28/100
# 88/88 [==============================] - 14s 163ms/step - loss: 2.2908 - accuracy: 0.1230 - val_loss: 2.2581 - val_accuracy: 0.1400
# Epoch 29/100
# 88/88 [==============================] - 15s 167ms/step - loss: 2.2730 - accuracy: 0.1411 - val_loss: 2.2544 - val_accuracy: 0.1404
# Epoch 30/100
# 88/88 [==============================] - 15s 168ms/step - loss: 2.2821 - accuracy: 0.1395 - val_loss: 2.2661 - val_accuracy: 0.1308
# Epoch 31/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2749 - accuracy: 0.1391 - val_loss: 2.2720 - val_accuracy: 0.1321
# Epoch 32/100
# 88/88 [==============================] - 15s 166ms/step - loss: 2.2749 - accuracy: 0.1412 - val_loss: 2.2404 - val_accuracy: 0.1646
# Epoch 33/100
# 88/88 [==============================] - 15s 173ms/step - loss: 2.2737 - accuracy: 0.1371 - val_loss: 2.2891 - val_accuracy: 0.1392
# Epoch 34/100
# 88/88 [==============================] - 16s 178ms/step - loss: 2.2637 - accuracy: 0.1470 - val_loss: 2.3094 - val_accuracy: 0.1404
# Epoch 35/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2678 - accuracy: 0.1432 - val_loss: 2.2389 - val_accuracy: 0.1608
# Epoch 36/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2722 - accuracy: 0.1445 - val_loss: 2.2486 - val_accuracy: 0.1558
# Epoch 37/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2710 - accuracy: 0.1389 - val_loss: 2.2817 - val_accuracy: 0.1292
# Epoch 38/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2675 - accuracy: 0.1430 - val_loss: 2.2435 - val_accuracy: 0.1654
# Epoch 39/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2620 - accuracy: 0.1513 - val_loss: 2.2471 - val_accuracy: 0.1558
# Epoch 40/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2610 - accuracy: 0.1529 - val_loss: 2.2793 - val_accuracy: 0.1400
# Epoch 41/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2697 - accuracy: 0.1437 - val_loss: 2.2532 - val_accuracy: 0.1558
# Epoch 42/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2649 - accuracy: 0.1477 - val_loss: 2.2366 - val_accuracy: 0.1442
# Epoch 43/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2599 - accuracy: 0.1466 - val_loss: 2.2437 - val_accuracy: 0.1658
# Epoch 44/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2592 - accuracy: 0.1411 - val_loss: 2.2346 - val_accuracy: 0.1754
# Epoch 45/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2570 - accuracy: 0.1546 - val_loss: 2.2237 - val_accuracy: 0.1887
# Epoch 46/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2599 - accuracy: 0.1437 - val_loss: 2.2275 - val_accuracy: 0.1729
# Epoch 47/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2659 - accuracy: 0.1539 - val_loss: 2.2397 - val_accuracy: 0.1721
# Epoch 48/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2653 - accuracy: 0.1462 - val_loss: 2.2291 - val_accuracy: 0.1762
# Epoch 49/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2605 - accuracy: 0.1489 - val_loss: 2.2783 - val_accuracy: 0.1554
# Epoch 50/100
# 88/88 [==============================] - 14s 163ms/step - loss: 2.2677 - accuracy: 0.1450 - val_loss: 2.2381 - val_accuracy: 0.1546
# Epoch 51/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2562 - accuracy: 0.1504 - val_loss: 2.2658 - val_accuracy: 0.1692
# Epoch 52/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2576 - accuracy: 0.1502 - val_loss: 2.2407 - val_accuracy: 0.1471
# Epoch 53/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2664 - accuracy: 0.1429 - val_loss: 2.2539 - val_accuracy: 0.1592
# Epoch 54/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2459 - accuracy: 0.1650 - val_loss: 2.2530 - val_accuracy: 0.1417
# Epoch 55/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2522 - accuracy: 0.1543 - val_loss: 2.2556 - val_accuracy: 0.1575
# Epoch 56/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2586 - accuracy: 0.1486 - val_loss: 2.2347 - val_accuracy: 0.1700
# Epoch 57/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2502 - accuracy: 0.1498 - val_loss: 2.2231 - val_accuracy: 0.1704
# Epoch 58/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2452 - accuracy: 0.1571 - val_loss: 2.2437 - val_accuracy: 0.1554
# Epoch 59/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2546 - accuracy: 0.1586 - val_loss: 2.2128 - val_accuracy: 0.1708
# Epoch 60/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2396 - accuracy: 0.1593 - val_loss: 2.2909 - val_accuracy: 0.1646
# Epoch 61/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2610 - accuracy: 0.1532 - val_loss: 2.2609 - val_accuracy: 0.1508
# Epoch 62/100
# 88/88 [==============================] - 15s 167ms/step - loss: 2.2471 - accuracy: 0.1616 - val_loss: 2.2204 - val_accuracy: 0.1833
# Epoch 63/100
# 88/88 [==============================] - 14s 165ms/step - loss: 2.2538 - accuracy: 0.1554 - val_loss: 2.2790 - val_accuracy: 0.1404
# Epoch 64/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2620 - accuracy: 0.1504 - val_loss: 2.2426 - val_accuracy: 0.1513
# Epoch 65/100
# 88/88 [==============================] - 14s 158ms/step - loss: 2.2493 - accuracy: 0.1541 - val_loss: 2.2721 - val_accuracy: 0.1521
# Epoch 66/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2511 - accuracy: 0.1604 - val_loss: 2.2257 - val_accuracy: 0.1663
# Epoch 67/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2491 - accuracy: 0.1646 - val_loss: 2.2096 - val_accuracy: 0.1808
# Epoch 68/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2441 - accuracy: 0.1605 - val_loss: 2.2115 - val_accuracy: 0.1804
# Epoch 69/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2287 - accuracy: 0.1721 - val_loss: 2.2206 - val_accuracy: 0.1787
# Epoch 70/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2313 - accuracy: 0.1654 - val_loss: 2.1981 - val_accuracy: 0.1892
# Epoch 71/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2294 - accuracy: 0.1793 - val_loss: 2.1966 - val_accuracy: 0.1821
# Epoch 72/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2319 - accuracy: 0.1671 - val_loss: 2.2239 - val_accuracy: 0.1637
# Epoch 73/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2442 - accuracy: 0.1575 - val_loss: 2.1914 - val_accuracy: 0.2037
# Epoch 74/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2320 - accuracy: 0.1759 - val_loss: 2.2261 - val_accuracy: 0.1742
# Epoch 75/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2388 - accuracy: 0.1589 - val_loss: 2.2065 - val_accuracy: 0.1692
# Epoch 76/100
# 88/88 [==============================] - 14s 164ms/step - loss: 2.2388 - accuracy: 0.1686 - val_loss: 2.1879 - val_accuracy: 0.1908
# Epoch 77/100
# 88/88 [==============================] - 14s 163ms/step - loss: 2.2418 - accuracy: 0.1579 - val_loss: 2.2137 - val_accuracy: 0.1917
# Epoch 78/100
# 88/88 [==============================] - 15s 165ms/step - loss: 2.2300 - accuracy: 0.1679 - val_loss: 2.1843 - val_accuracy: 0.2008
# Epoch 79/100
# 88/88 [==============================] - 14s 164ms/step - loss: 2.2321 - accuracy: 0.1743 - val_loss: 2.2029 - val_accuracy: 0.1917
# Epoch 80/100
# 88/88 [==============================] - 15s 166ms/step - loss: 2.2259 - accuracy: 0.1768 - val_loss: 2.2386 - val_accuracy: 0.1504
# Epoch 81/100
# 88/88 [==============================] - 14s 163ms/step - loss: 2.2310 - accuracy: 0.1696 - val_loss: 2.1937 - val_accuracy: 0.1775
# Epoch 82/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2295 - accuracy: 0.1655 - val_loss: 2.1919 - val_accuracy: 0.1912
# Epoch 83/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2313 - accuracy: 0.1675 - val_loss: 2.1878 - val_accuracy: 0.1892
# Epoch 84/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2261 - accuracy: 0.1759 - val_loss: 2.1944 - val_accuracy: 0.1838
# Epoch 85/100
# 88/88 [==============================] - 14s 164ms/step - loss: 2.2213 - accuracy: 0.1798 - val_loss: 2.1779 - val_accuracy: 0.1896
# Epoch 86/100
# 88/88 [==============================] - 15s 166ms/step - loss: 2.2283 - accuracy: 0.1689 - val_loss: 2.2034 - val_accuracy: 0.1725
# Epoch 87/100
# 88/88 [==============================] - 15s 166ms/step - loss: 2.2282 - accuracy: 0.1745 - val_loss: 2.1868 - val_accuracy: 0.1758
# Epoch 88/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.2197 - accuracy: 0.1762 - val_loss: 2.1864 - val_accuracy: 0.1879
# Epoch 89/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2277 - accuracy: 0.1730 - val_loss: 2.2802 - val_accuracy: 0.1412
# Epoch 90/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2322 - accuracy: 0.1695 - val_loss: 2.2643 - val_accuracy: 0.1517
# Epoch 91/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2197 - accuracy: 0.1768 - val_loss: 2.1939 - val_accuracy: 0.1679
# Epoch 92/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2304 - accuracy: 0.1655 - val_loss: 2.2260 - val_accuracy: 0.1679
# Epoch 93/100
# 88/88 [==============================] - 14s 159ms/step - loss: 2.2293 - accuracy: 0.1663 - val_loss: 2.2759 - val_accuracy: 0.1521
# Epoch 94/100
# 88/88 [==============================] - 14s 164ms/step - loss: 2.2117 - accuracy: 0.1857 - val_loss: 2.1800 - val_accuracy: 0.1983
# Epoch 95/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2187 - accuracy: 0.1798 - val_loss: 2.2444 - val_accuracy: 0.1550
# Epoch 96/100
# 88/88 [==============================] - 14s 161ms/step - loss: 2.2160 - accuracy: 0.1782 - val_loss: 2.2125 - val_accuracy: 0.1817
# Epoch 97/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2147 - accuracy: 0.1809 - val_loss: 2.1665 - val_accuracy: 0.1979
# Epoch 98/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2229 - accuracy: 0.1857 - val_loss: 2.1734 - val_accuracy: 0.2042
# Epoch 99/100
# 88/88 [==============================] - 14s 160ms/step - loss: 2.2037 - accuracy: 0.1866 - val_loss: 2.1635 - val_accuracy: 0.2225
# Epoch 100/100
# 88/88 [==============================] - 14s 162ms/step - loss: 2.1974 - accuracy: 0.1914 - val_loss: 2.1742 - val_accuracy: 0.1963

# %%
import matplotlib.pyplot as plt


plt.figure(figsize=(12, 6))

# Loss
plt.subplot(1, 2, 1)  
plt.plot(history.history['loss'], label='Training Loss')
if 'val_loss' in history.history:  
    plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss Curve')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()

#Accuracy
plt.subplot(1, 2, 2)
plt.plot(history.history['accuracy'], label='Training Accuracy')
if 'val_accuracy' in history.history:  
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy Curve')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout()
plt.show()
